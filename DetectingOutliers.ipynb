# %% [markdown]
# <a href="https://colab.research.google.com/github/shaswath-29/EDA_LABORATORY_ASSIGNMENT/blob/Exp5_04.08.2026/DetectingOutliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/fraudTest.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
# 5           5   2020-06-21 12:15:37    30407675418785
# 6           6   2020-06-21 12:15:44   213180742685905
# 7           7   2020-06-21 12:15:50  3589289942931264
# 8           8   2020-06-21 12:16:10  3596357274378601
# 9           9   2020-06-21 12:16:11  3546897637165774
#
#                                merchant        category     amt     first  \
# 0                 fraud_Kirlin and Sons   personal_care    2.86      Jeff
# 1                  fraud_Sporer-Keebler   personal_care   29.84    Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28    Ashley
# ...

# %%
df['TotalPrice'] = df['amt']
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
import numpy as np
TotalTransaction = df["TotalPrice"]
TotalTransaction[np.abs(TotalTransaction) > 30.0]
# Out:
# 2          41.28
# 3          60.05
# 6         133.93
# 9          66.54
# 11         42.40
#            ...
# 555709     46.71
# 555714     43.77
# 555715    111.84
# 555716     86.88
# 555718     38.13
# Name: TotalPrice, Length: 339976, dtype: float64

# %%
df[np.abs(TotalTransaction) > 674.1112]
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 167            167   2020-06-21 13:08:46     6011109736646996
# 428            428   2020-06-21 14:38:09       38530489946071
# 720            720   2020-06-21 16:18:24      343472729187663
# 728            728   2020-06-21 16:22:15     3518234918950662
# 951            951   2020-06-21 17:40:54  4292743669224718067
# ...            ...                   ...                  ...
# 554553      554553   2020-12-31 17:17:41     3582754887089201
# 555004      555004   2020-12-31 19:43:11     4364010865167176
# 555229      555229   2020-12-31 21:08:01       36913587729122
# 555495      555495   2020-12-31 22:36:21         630451534402
# 555637      555637   2020-12-31 23:30:29     6011109736646996
#
#                                      merchant      category      amt  \
# 167                          fraud_Schumm PLC  shopping_net  1199.45
# 428                          fraud_Metz-Boehm  shopping_pos  1881.53
# ...

# %%
df = pd.read_csv('/fraudTrain.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
# 5           5   2019-01-01 00:04:08  4767265376804500
# 6           6   2019-01-01 00:04:42    30074693890476
# 7           7   2019-01-01 00:05:08  6011360759745864
# 8           8   2019-01-01 00:05:18  4922710831011201
# 9           9   2019-01-01 00:06:01  2720830304681674
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# ...

# %%
df['TotalPrice'] = df['amt']
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2019-01-01 00:00:18  2703186189652095
# 1                1   2019-01-01 00:00:44      630423337322
# 2                2   2019-01-01 00:00:51    38859492057661
# 3                3   2019-01-01 00:01:16  3534093764340240
# 4                4   2019-01-01 00:03:06   375534208663984
# ...            ...                   ...               ...
# 596834      596834   2019-09-09 22:57:42  4173950183554608
# 596835      596835   2019-09-09 22:58:55  3512365128314616
# 596836      596836   2019-09-09 23:00:02  4670613943676271
# 596837      596837   2019-09-09 23:00:09    30199621383748
# 596838      596838   2019-09-09 23:00:33  6011542681743618
#
#                                       merchant        category     amt  \
# 0                   fraud_Rippin, Kub and Mann        misc_net    4.97
# 1              fraud_Heller, Gutmann and Zieme     grocery_pos  107.23
# ...

# %%
import numpy as np
TotalTransaction = df["TotalPrice"]
TotalTransaction[np.abs(TotalTransaction) > 30.0]
# Out:
# 1         107.23
# 2         220.11
# 3          45.00
# 4          41.96
# 5          94.63
#            ...
# 596827     33.94
# 596830    157.22
# 596831     89.53
# 596832     55.07
# 596833    148.52
# Name: TotalPrice, Length: 365255, dtype: float64

# %%
df[np.abs(TotalTransaction) > 674.1112]
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 232            232   2019-01-01 02:54:10  4311368326621416041
# 296            296   2019-01-01 03:51:28         571844099986
# 511            511   2019-01-01 06:43:54     4509142395811241
# 723            723   2019-01-01 09:23:55     4265776278887457
# 770            770   2019-01-01 09:53:44       38580485618059
# ...            ...                   ...                  ...
# 596400      596400   2019-09-09 20:21:14     6011329966782895
# 596631      596631   2019-09-09 21:44:01         676314217768
# 596731      596731   2019-09-09 22:22:33       30499715231997
# 596806      596806   2019-09-09 22:48:17       30199621383748
# 596812      596812   2019-09-09 22:49:38       30499715231997
#
#                                    merchant      category      amt      first  \
# 232                      fraud_Kassulke PLC  shopping_net  1055.47    Phillip
# ...
