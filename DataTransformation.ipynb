# %% [markdown]
# <a href="https://colab.research.google.com/github/shaswath-29/EDA_LABORATORY_ASSIGNMENT/blob/Exp5_04.08.2026/DataTransformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,StandardScaler, RobustScaler
data = {"Study Hours":[2,4,6,8,10],
        "Marks": [45,60,72,88,250]}
df = pd.DataFrame(data)
print("Original Data:\n")
print(df)
print()
# Out:
# Original Data:
#
#    Study Hours  Marks
# 0            2     45
# 1            4     60
# 2            6     72
# 3            8     88
# 4           10    250

# %%
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(min_max_scaler.fit_transform(df),columns = df.columns)
print("Min-Max Scaled Data:\n")
print(df_min_max)
print()
# Out:
# Min-Max Scaled Data:
#
#    Study Hours     Marks
# 0         0.00  0.000000
# 1         0.25  0.073171
# 2         0.50  0.131707
# 3         0.75  0.209756
# 4         1.00  1.000000
